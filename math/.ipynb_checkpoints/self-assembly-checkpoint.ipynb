# %% [markdown]
# # Self-assembly
#
# A recombination of evolutionary computing and cellular automata.

# %%
import research as r
import scipy
import pandas

def fitness_plots(path, treatment):
    F = r.find_files(path, treatment+"_.*/fitness.dat")
    D = r.load_files(F)

    figure()
    for i,g in D.groupby('trial'):
        plot(g['update'], g['max_fitness'])
    ylabel('Fitness')
    xlabel('Update')
    
    figure()
    r.quick_ciplot('update','max_fitness', D)
    ylabel('Fitness')
    xlabel('Update')
#    savefig("centroid.pdf")
    final = D[D['update']==D['update'].max()]
    print "\nDominant fitness:"
    print final.ix[final['max_fitness'].idxmax()]
    print "\nn:", len(F)
    return D

# %% [markdown]
# ## 4/15/2014: 008-1d-fsm-rand
#
# Here we randomly change the goal from majority to minority...

# %%
D = fitness_plots('../var/008-1d-fsm-rand','ta0') # logic gates only
# Out:
# Dominant fitness:
# update              10000
# mean_generation    29.736
# min_fitness        0.9455
# mean_fitness       0.9985
# max_fitness             1
# treatment             ta0
# trial                   1
# Name: 1000, dtype: object
#
# n: 30

# %% [markdown]
# ## 4/14/2014: 005-1d-fsm-rl
#
# 1D FSM, but we add a feedback bit.  Expect to see some improvement with adaptive gates...

# %%
D = fitness_plots('../var/005-1d-fsm-rl','ta0') # logic gates only
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-75-7fe9a5e61fc6> in <module>()
# ----> 1 D = fitness_plots('../var/005-1d-fsm-rl','ta0') # logic gates only
#
# <ipython-input-38-77ce27a61fe6> in fitness_plots(path, treatment)
#      14
#      15     figure()
# ---> 16     r.quick_ciplot('update','max_fitness', D)
#      17     ylabel('Fitness')
#      18     xlabel('Update')
#
# /Users/dk/research/share/python/research/quick.pyc in quick_ciplot(x, y, D)
#      13
#      14 def quick_ciplot(x, y, D):
# ---> 15     R = pandas.DataFrame(D.groupby(x)[y].apply(quick_ci, x))
#      16     l, = mp.plot(R[x], R['mean'])
#      17     mp.fill_between(R[x], R['low'], R['high'], facecolor=l.get_color(), alpha=0.5)
#
# /Users/dk/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/core/groupby.pyc in apply(self, func, *args, **kwargs)
#     422             return func(g, *args, **kwargs)
#     423
# --> 424         return self._python_apply_general(f)
#     425
#     426     def _python_apply_general(self, f):
#
# /Users/dk/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/core/groupby.pyc in _python_apply_general(self, f)
#     425
#     426     def _python_apply_general(self, f):
# --> 427         keys, values, mutated = self.grouper.apply(f, self.obj, self.axis)
#     428
#     429         return self._wrap_applied_output(keys, values,
#
# /Users/dk/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/core/groupby.pyc in apply(self, f, data, axis)
#     881             # group might be modified
#     882             group_axes = _get_axes(group)
# --> 883             res = f(group)
#     884             if not _is_indexed_like(res, group_axes):
#     885                 mutated = True
#
# /Users/dk/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/core/groupby.pyc in f(g)
#     420         @wraps(func)
#     421         def f(g):
# --> 422             return func(g, *args, **kwargs)
#     423
#     424         return self._python_apply_general(f)
#
# /Users/dk/research/share/python/research/quick.pyc in quick_ci(g, x, fun, alpha, n)
#       9     import warnings
#      10     warnings.simplefilter("ignore",bootstrap.InstabilityWarning)
# ---> 11     l,h = bootstrap.ci(data=g, statfunction=fun, alpha=alpha, n_samples=n)
#      12     return pandas.DataFrame({x:g.name, 'mean':g.mean(), 'low':l, 'high':h}, index=[g.name])
#      13
#
# /Users/dk/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/scikits.bootstrap-0.3.1-py2.7.egg/scikits/bootstrap/bootstrap.pyc in ci(data, statfunction, alpha, n_samples, method, output, epsilon, multi)
#     205         if nvals.ndim == 1:
#     206             # All nvals are the same. Simple broadcasting
# --> 207             return stat[nvals]
#     208         else:
#     209             # Nvals are different for each data point. Not simple broadcasting.
#
# IndexError: index -9223372036854775808 is out of bounds for size 200

# %%
D = fitness_plots('../var/005-1d-fsm-rl','tb0') # logic+prob
# Out:
# Dominant fitness:
# update              10000
# mean_generation    28.796
# min_fitness        0.9155
# mean_fitness       0.9981
# max_fitness             1
# treatment             tb0
# trial                   1
# Name: 1000, dtype: object
#
# n: 30

# %%
D = fitness_plots('../var/005-1d-fsm-rl','tc0') # logic+adaptive
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-77-a5654c0edc32> in <module>()
# ----> 1 D = fitness_plots('../var/005-1d-fsm-rl','tc0') # logic+adaptive
#
# <ipython-input-38-77ce27a61fe6> in fitness_plots(path, treatment)
#      14
#      15     figure()
# ---> 16     r.quick_ciplot('update','max_fitness', D)
#      17     ylabel('Fitness')
#      18     xlabel('Update')
#
# /Users/dk/research/share/python/research/quick.pyc in quick_ciplot(x, y, D)
#      13
#      14 def quick_ciplot(x, y, D):
# ---> 15     R = pandas.DataFrame(D.groupby(x)[y].apply(quick_ci, x))
#      16     l, = mp.plot(R[x], R['mean'])
#      17     mp.fill_between(R[x], R['low'], R['high'], facecolor=l.get_color(), alpha=0.5)
#
# /Users/dk/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/core/groupby.pyc in apply(self, func, *args, **kwargs)
#     422             return func(g, *args, **kwargs)
#     423
# --> 424         return self._python_apply_general(f)
#     425
#     426     def _python_apply_general(self, f):
#
# /Users/dk/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/core/groupby.pyc in _python_apply_general(self, f)
#     425
#     426     def _python_apply_general(self, f):
# --> 427         keys, values, mutated = self.grouper.apply(f, self.obj, self.axis)
#     428
#     429         return self._wrap_applied_output(keys, values,
#
# /Users/dk/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/core/groupby.pyc in apply(self, f, data, axis)
#     881             # group might be modified
#     882             group_axes = _get_axes(group)
# --> 883             res = f(group)
#     884             if not _is_indexed_like(res, group_axes):
#     885                 mutated = True
#
# /Users/dk/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/core/groupby.pyc in f(g)
#     420         @wraps(func)
#     421         def f(g):
# --> 422             return func(g, *args, **kwargs)
#     423
#     424         return self._python_apply_general(f)
#
# /Users/dk/research/share/python/research/quick.pyc in quick_ci(g, x, fun, alpha, n)
#       9     import warnings
#      10     warnings.simplefilter("ignore",bootstrap.InstabilityWarning)
# ---> 11     l,h = bootstrap.ci(data=g, statfunction=fun, alpha=alpha, n_samples=n)
#      12     return pandas.DataFrame({x:g.name, 'mean':g.mean(), 'low':l, 'high':h}, index=[g.name])
#      13
#
# /Users/dk/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/scikits.bootstrap-0.3.1-py2.7.egg/scikits/bootstrap/bootstrap.pyc in ci(data, statfunction, alpha, n_samples, method, output, epsilon, multi)
#     205         if nvals.ndim == 1:
#     206             # All nvals are the same. Simple broadcasting
# --> 207             return stat[nvals]
#     208         else:
#     209             # Nvals are different for each data point. Not simple broadcasting.
#
# IndexError: index -9223372036854775808 is out of bounds for size 200

# %% [markdown]
# ## 4/7/2014: 004-3d-fsm
#
# First cut at 3D CAs evolved with state machines.

# %%
D = fitness_plots('../var/004-3d-fsm','ta0') # logic gates only
# Out:
# Dominant fitness:
# update              10000
# mean_generation    62.594
# min_fitness        0.9045
# mean_fitness       0.9877
# max_fitness        0.9918
# treatment             ta0
# trial                  11
# Name: 3002, dtype: object
#
# n: 28

# %%
D = fitness_plots('../var/004-3d-fsm','tb0') # logic+probabilistic gates only
# Out:
# Dominant fitness:
# update              10000
# mean_generation    72.614
# min_fitness        0.9018
# mean_fitness       0.9793
# max_fitness        0.9836
# treatment             tb0
# trial                   3
# Name: 23022, dtype: object
#
# n: 30

# %%
D = fitness_plots('../var/004-3d-fsm','tc0') # logic+adaptive gates only
# Out:
# Dominant fitness:
# update              10000
# mean_generation    81.764
# min_fitness        0.9318
# mean_fitness       0.9753
# max_fitness          0.98
# treatment             tc0
# trial                  28
# Name: 5004, dtype: object
#
# n: 7

# %% [markdown]
# ## 4/6/2014: 003-2d-fsm
#
# First cut at 2D CAs evolved with state machines.

# %%
D = fitness_plots('../var/003-2d-fsm','ta0') # logic gates only
# Out:
# Dominant fitness:
# update              10000
# mean_generation    93.858
# min_fitness        0.9445
# mean_fitness       0.9907
# max_fitness        0.9955
# treatment             ta0
# trial                  13
# Name: 5004, dtype: object
#
# n: 30

# %%
D = fitness_plots('../var/003-2d-fsm','tb0') # logic+probabilistic gates only
# Out:
# Dominant fitness:
# update               10000
# mean_generation    126.092
# min_fitness         0.9045
# mean_fitness        0.9829
# max_fitness         0.9873
# treatment              tb0
# trial                   10
# Name: 2001, dtype: object
#
# n: 30

# %%
D = fitness_plots('../var/003-2d-fsm','tc0') # logic+adaptive gates only
# Out:
# Dominant fitness:
# update              10000
# mean_generation     82.84
# min_fitness        0.9355
# mean_fitness        0.982
# max_fitness        0.9864
# treatment             tc0
# trial                  13
# Name: 3002, dtype: object
#
# n: 12

# %% [markdown]
# ## 4/3/2014: 002-1d-fsm
#
# First cut at evolving cellular automata with state machines.  1D only; ta0=logic, tb0=logic+prob, and tc0=logic+adaptive gates.

# %%
D = fitness_plots('../var/002-1d-fsm','ta0') # logic gates only
# Out:
# Dominant fitness:
# update              10000
# mean_generation     85.17
# min_fitness          0.91
# mean_fitness       0.9884
# max_fitness        0.9918
# treatment             ta0
# trial                  14
# Name: 6005, dtype: object
#
# n: 30

# %%
D = fitness_plots('../var/002-1d-fsm','tb0') # logic+probabilistic
# Out:
# Dominant fitness:
# update              10000
# mean_generation     95.59
# min_fitness        0.9045
# mean_fitness       0.9861
# max_fitness        0.9909
# treatment             tb0
# trial                   8
# Name: 29028, dtype: object
#
# n: 30

# %%
D = fitness_plots('../var/002-1d-fsm','tc0') # logic+adaptive
# Out:
# Dominant fitness:
# update              10000
# mean_generation    82.132
# min_fitness        0.9536
# mean_fitness       0.9997
# max_fitness             1
# treatment             tc0
# trial                  11
# Name: 3002, dtype: object
#
# n: 25

# %% [markdown]
# ## < 4/3/2014: 001-ga
#
# Replicating work by Mitchell et al.

# %%
D = fitness_plots('../var/001-ga','ta0')
# Out:
# Dominant fitness:
# update                100
# mean_generation     68.15
# min_fitness          0.01
# mean_fitness       0.7955
# max_fitness          0.99
# treatment             ta0
# trial                  11
# Name: 302, dtype: object
#
# n: 30
